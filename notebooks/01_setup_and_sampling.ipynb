# %% [markdown]
# # 01 — Setup & Sampling (Minimal)

# %%
import pandas as pd
RAW_FILE = "application_train.csv"
DATA_PATH = r"C:\Users\felix\hci_final_project\data\raw"
SAMPLE_PATH = r"C:\Users\felix\hci_final_project\data\sample"
df_head = pd.read_csv(f"{DATA_PATH}\\{RAW_FILE}", nrows=5, low_memory=False)
df_head.columns.tolist()[:12], df_head.shape
# Out:
# (['SK_ID_CURR',
#   'TARGET',
#   'NAME_CONTRACT_TYPE',
#   'CODE_GENDER',
#   'FLAG_OWN_CAR',
#   'FLAG_OWN_REALTY',
#   'CNT_CHILDREN',
#   'AMT_INCOME_TOTAL',
#   'AMT_CREDIT',
#   'AMT_ANNUITY',
#   'AMT_GOODS_PRICE',
#   'NAME_TYPE_SUITE'],
#  (5, 122))

# %%
TARGET = "TARGET"  
pd.read_csv(f"{DATA_PATH}\\{RAW_FILE}", usecols=[TARGET])[TARGET].value_counts(normalize=True)
# Out:
# TARGET
# 0    0.919271
# 1    0.080729
# Name: proportion, dtype: float64

# %% [markdown]
# Checking TARGET proportion because of imbalance

# %%
full = pd.read_csv(f"{DATA_PATH}\\{RAW_FILE}", low_memory=False)
miss = full.isna().mean().sort_values(ascending=False).head(30)
const_cols = [c for c in full.columns if full[c].nunique(dropna=False)==1]
miss, const_cols[:10]
# Out:
# (COMMONAREA_AVG              0.698723
#  COMMONAREA_MODE             0.698723
#  COMMONAREA_MEDI             0.698723
#  NONLIVINGAPARTMENTS_MEDI    0.694330
#  NONLIVINGAPARTMENTS_MODE    0.694330
#  NONLIVINGAPARTMENTS_AVG     0.694330
#  FONDKAPREMONT_MODE          0.683862
#  LIVINGAPARTMENTS_AVG        0.683550
#  LIVINGAPARTMENTS_MEDI       0.683550
#  LIVINGAPARTMENTS_MODE       0.683550
#  FLOORSMIN_MODE              0.678486
#  FLOORSMIN_AVG               0.678486
#  FLOORSMIN_MEDI              0.678486
#  YEARS_BUILD_AVG             0.664978
#  YEARS_BUILD_MODE            0.664978
#  YEARS_BUILD_MEDI            0.664978
#  OWN_CAR_AGE                 0.659908
#  LANDAREA_MEDI               0.593767
#  LANDAREA_AVG                0.593767
#  LANDAREA_MODE               0.593767
#  BASEMENTAREA_MODE           0.585160
#  BASEMENTAREA_MEDI           0.585160
#  BASEMENTAREA_AVG            0.585160
#  EXT_SOURCE_1                0.563811
#  NONLIVINGAREA_MODE          0.551792
# ...

# %% [markdown]
# Calculating column with most NaN

# %%
pos_total = int(full[TARGET].sum())
min_pos = 1000                             
frac = min(0.10, max(0.01, min_pos / max(pos_total, 1)))  
frac
# Out:
# 0.04028197381671702

# %% [markdown]
# sampling with 0.10 and 0.01

# %%
sample = full.groupby(TARGET, group_keys=False).sample(frac=frac, random_state=42)
sample_ids = set(sample["SK_ID_CURR"])
sample.to_csv("C:\\Users\\felix\\hci_final_project\\data\\sample\\application_train_sample.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[38], line 3
#       1 sample = full.groupby(TARGET, group_keys=False).sample(frac=frac, random_state=42)
#       2 sample_ids = set(sample["SK_ID_CURR"])
# ----> 3 sample.to_csv(f"{SAMPLE_PATH}\\application_train_sample.csv", index=False)
#
# File c:\Users\felix\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# Make a stratified sample

# %%
sample[TARGET].value_counts(normalize=True)
# Out:
# TARGET
# 0    0.91927
# 1    0.08073
# Name: proportion, dtype: float64

# %%
bureau = pd.read_csv("C:\\Users\\felix\\hci_final_project\\data\\raw\\bureau.csv", low_memory=False)
bureau_s = bureau[bureau["SK_ID_CURR"].isin(sample_ids)]
bureau_s.to_csv("C:\\Users\\felix\\hci_final_project\\data\\sample\\bureau_sample.csv", index=False)

prev = pd.read_csv("C:\\Users\\felix\\hci_final_project\\data\\raw\\previous_application.csv", low_memory=False)
prev_s = prev[prev["SK_ID_CURR"].isin(sample_ids)]
prev_s.to_csv("C:\\Users\\felix\\hci_final_project\\data\\sample\\previous_application_sample.csv", index=False)
